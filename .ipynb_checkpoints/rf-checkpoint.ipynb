# %%
import numpy as np
import pandas as pd
import sklearn as sk
import xgboost as xgb

from scipy import sparse
from itertools import combinations
from scipy.sparse import coo_matrix, hstack
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

def find_index(value, li):
    l = len(li)
    for i in range(l):
        if(li[i] == value):
            return i
    return -1


def find_best_value_for_parameter(X, y, other_parameter_values,
                                  parameter_name,
                                 first_level_values,
                                 second_level_values):
    grid = {parameter_name: first_level_values}
    clf = RandomForestClassifier()
    clf.set_params(**other_parameter_values)
    grid_search = GridSearchCV(estimator = clf, param_grid = grid, scoring='roc_auc', cv=5, verbose=100)
    grid_search.fit(X, y)
    ind = find_index(grid_search.best_params_[parameter_name], first_level_values)
    if(ind == -1):
        return grid_search.best_params_[parameter_name]
    else:
        grid = {parameter_name: second_level_values[ind]}
        grid_search = GridSearchCV(estimator = clf, param_grid = grid, scoring='roc_auc', cv=5, verbose=100)
        grid_search.fit(X, y)
        return grid_search.best_params_[parameter_name]

if __name__ == "__main__": 
    # load data
    df_train = pd.read_csv('train_art.csv')
    df_test = pd.read_csv('test_art.csv')
    print df_train.shape
    # remove columns with 0 variance
    remove = []
    cols = df_train.columns
    for i in range(len(cols)-1):
        if df_train[cols[i]].std() == 0:
            remove.append(cols[i])

    # remove duplicated columns
    for i in range(len(cols)-1):
        v = df_train[cols[i]].values
        for j in range(i+1,len(cols)):
            if np.array_equal(v,df_train[cols[j]].values):
                remove.append(cols[j])	

    df_train.drop(remove, axis=1, inplace=True)
    df_test.drop(remove, axis=1, inplace=True)
    
    tokeep = ['num_var39_0',  # 0.00031104199066874026
              'ind_var13',  # 0.00031104199066874026
              'num_op_var41_comer_ult3',  # 0.00031104199066874026
              'num_var43_recib_ult1',  # 0.00031104199066874026
              'imp_op_var41_comer_ult3',  # 0.00031104199066874026
              'num_var8',  # 0.00031104199066874026
              'num_var42',  # 0.00031104199066874026
              'num_var30',  # 0.00031104199066874026
              'saldo_var8',  # 0.00031104199066874026
              'num_op_var39_efect_ult3',  # 0.00031104199066874026
              'num_op_var39_comer_ult3',  # 0.00031104199066874026
              'num_var41_0',  # 0.0006220839813374805
              'num_op_var39_ult3',  # 0.0006220839813374805
              'saldo_var13',  # 0.0009331259720062209
              'num_var30_0',  # 0.0009331259720062209
              'ind_var37_cte',  # 0.0009331259720062209
              'ind_var39_0',  # 0.001244167962674961
              'num_var5',  # 0.0015552099533437014
              'ind_var10_ult1',  # 0.0015552099533437014
              'num_op_var39_hace2',  # 0.0018662519440124418
              'num_var22_hace2',  # 0.0018662519440124418
              'num_var35',  # 0.0018662519440124418
              'ind_var30',  # 0.0018662519440124418
              'num_med_var22_ult3',  # 0.002177293934681182
              'imp_op_var41_efect_ult1',  # 0.002488335925349922
              'var36',  # 0.0027993779160186624
              'num_med_var45_ult3',  # 0.003110419906687403
              'imp_op_var39_ult1',  # 0.0037325038880248835
              'imp_op_var39_comer_ult3',  # 0.0037325038880248835
              'imp_trans_var37_ult1',  # 0.004043545878693624
              'num_var5_0',  # 0.004043545878693624
              'num_var45_ult1',  # 0.004665629860031105
              'ind_var41_0',  # 0.0052877138413685845
              'imp_op_var41_ult1',  # 0.0052877138413685845
              'num_var8_0',  # 0.005598755832037325
              'imp_op_var41_efect_ult3',  # 0.007153965785381027
              'num_op_var41_ult3',  # 0.007153965785381027
              'num_var22_hace3',  # 0.008087091757387248
              'num_var4',  # 0.008087091757387248
              'imp_op_var39_comer_ult1',  # 0.008398133748055987
              'num_var45_ult3',  # 0.008709175738724729
              'ind_var5',  # 0.009953343701399688
              'imp_op_var39_efect_ult3',  # 0.009953343701399688
              'num_meses_var5_ult3',  # 0.009953343701399688
              'saldo_var42',  # 0.01181959564541213
              'imp_op_var39_efect_ult1',  # 0.013374805598755831
              'num_var45_hace2',  # 0.014618973561430793
              'num_var22_ult1',  # 0.017107309486780714
              'saldo_medio_var5_ult1',  # 0.017418351477449457
              'saldo_var5',  # 0.0208398133748056
              'ind_var8_0',  # 0.021150855365474338
              'ind_var5_0',  # 0.02177293934681182
              'num_meses_var39_vig_ult3',  # 0.024572317262830483
              'saldo_medio_var5_ult3',  # 0.024883359253499222
              'num_var45_hace3',  # 0.026749611197511663
              'num_var22_ult3',  # 0.03452566096423017
              'saldo_medio_var5_hace3',  # 0.04074650077760498
              'saldo_medio_var5_hace2',  # 0.04292379471228616
              'n0',  # 0.04696734059097978
              'saldo_var30',  # 0.09611197511664074
              'var38',  # 0.1390357698289269
              'var15', 'art_var3', 'art_var36', 'art_var38mc', 'art_logvar38','pca0', 'pca1', 'pca2', 'pca3', 'pca4', 'pca5', 'pca6', 'pca7', 'pca8', 'pca9', 'pca_all0', 'pca_all1', 'pca_all2', 'pca_all3', 'pca_all4', 'pca_all5', 'pca_all6', 'pca_all7', 'pca_all8', 'pca_all9'] 

    #df_train.replace(0, np.nan, True).to_sparse()
    #df_test.replace(0, np.nan, True).to_sparse()
    #0 if np.isnan(i) else 1
    y = df_train.ix[:,-1]; X = pd.DataFrame.as_matrix(df_train[tokeep])
    y_test = df_test.ix[:,0]; X_test = pd.DataFrame.as_matrix(df_test[tokeep])
# Out:
# (76020, 396)

# %%
    other_parameter_values = {'n_estimators': 270, 'max_features': 4, 
                              'max_depth': 23, 'min_samples_leaf': 2,
                              'min_samples_split':8, 'criterion':'entropy'}
    parameter_name = 'n_estimators'
    other_parameter_values[parameter_name] = find_best_value_for_parameter(X, y, other_parameter_values,
                                                                          parameter_name,
                                                                          [50,100,200],
                                                                          {0:[50,60,70,80,90],
                                                                           1:[100,120,140,160,180],
                                                                           2:[200,240,280,320,360]})
    forest = RandomForestClassifier()
    forest.set_params(**other_parameter_values)
    forest.fit(X,y)

    # testing
    y_test_pred = forest.predict_proba(X_test)
    ans = pd.DataFrame({'ID': y_test, 'TARGET' : y_test_pred[:,1]})
    ans.to_csv('rf'+'.csv', index=False, columns=['ID', 'TARGET'])

# %%
    print other_parameter_values
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] n_estimators=50 .................................................
# [CV] ........................ n_estimators=50, score=0.798524 -   7.3s
# [Parallel(n_jobs=1)]: Done   1 tasks       | elapsed:    7.3s
# [CV] n_estimators=50 .................................................
# [CV] ........................ n_estimators=50, score=0.795962 -   6.9s
# [Parallel(n_jobs=1)]: Done   2 tasks       | elapsed:   14.3s
# [CV] n_estimators=50 .................................................
# [CV] ........................ n_estimators=50, score=0.806035 -   7.0s
# [Parallel(n_jobs=1)]: Done   3 tasks       | elapsed:   21.3s
# [CV] n_estimators=50 .................................................
# [CV] ........................ n_estimators=50, score=0.826945 -   9.0s
# [Parallel(n_jobs=1)]: Done   4 tasks       | elapsed:   30.4s
# [CV] n_estimators=50 .................................................
# [CV] ........................ n_estimators=50, score=0.812270 -  10.9s
# [Parallel(n_jobs=1)]: Done   5 tasks       | elapsed:   41.3s
# [CV] n_estimators=100 ................................................
# [CV] ....................... n_estimators=100, score=0.799162 -  15.5s
# [Parallel(n_jobs=1)]: Done   6 tasks       | elapsed:   56.9s
# [CV] n_estimators=100 ................................................
# [CV] ....................... n_estimators=100, score=0.799720 -  13.4s
# [Parallel(n_jobs=1)]: Done   7 tasks       | elapsed:  1.2min
# [CV] n_estimators=100 ................................................
# [CV] ....................... n_estimators=100, score=0.809931 -  13.7s
# [Parallel(n_jobs=1)]: Done   8 tasks       | elapsed:  1.4min
# [CV] n_estimators=100 ................................................
# [CV] ....................... n_estimators=100, score=0.826913 -  14.4s
# [Parallel(n_jobs=1)]: Done   9 tasks       | elapsed:  1.6min
# [CV] n_estimators=100 ................................................
# [CV] ....................... n_estimators=100, score=0.816260 -  13.6s
# [Parallel(n_jobs=1)]: Done  10 tasks       | elapsed:  1.9min
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.807658 -  27.4s
# [Parallel(n_jobs=1)]: Done  11 tasks       | elapsed:  2.3min
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.805079 -  33.6s
# [Parallel(n_jobs=1)]: Done  12 tasks       | elapsed:  2.9min
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.812278 -  50.8s
# [Parallel(n_jobs=1)]: Done  13 tasks       | elapsed:  3.7min
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.833375 -  46.3s
# [Parallel(n_jobs=1)]: Done  14 tasks       | elapsed:  4.5min
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.816470 -  29.5s
# [Parallel(n_jobs=1)]: Done  15 tasks       | elapsed:  5.0min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  5.0min finished
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.807334 -  33.7s
# [Parallel(n_jobs=1)]: Done   1 tasks       | elapsed:   33.8s
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.805893 -  33.1s
# [Parallel(n_jobs=1)]: Done   2 tasks       | elapsed:  1.1min
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.810630 -  33.5s
# [Parallel(n_jobs=1)]: Done   3 tasks       | elapsed:  1.7min
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.833026 -  28.7s
# [Parallel(n_jobs=1)]: Done   4 tasks       | elapsed:  2.2min
# [CV] n_estimators=200 ................................................
# [CV] ....................... n_estimators=200, score=0.816949 -  29.7s
# [Parallel(n_jobs=1)]: Done   5 tasks       | elapsed:  2.6min
# [CV] n_estimators=240 ................................................
# [CV] ....................... n_estimators=240, score=0.810034 -  37.8s
# [Parallel(n_jobs=1)]: Done   6 tasks       | elapsed:  3.3min
# [CV] n_estimators=240 ................................................
# [CV] ....................... n_estimators=240, score=0.805945 -  35.0s
# [Parallel(n_jobs=1)]: Done   7 tasks       | elapsed:  3.9min
# [CV] n_estimators=240 ................................................
# [CV] ....................... n_estimators=240, score=0.812274 -  39.3s
# [Parallel(n_jobs=1)]: Done   8 tasks       | elapsed:  4.5min
# [CV] n_estimators=240 ................................................
# [CV] ....................... n_estimators=240, score=0.832368 -  37.3s
# [Parallel(n_jobs=1)]: Done   9 tasks       | elapsed:  5.1min
# [CV] n_estimators=240 ................................................
# [CV] ....................... n_estimators=240, score=0.819056 -  35.9s
# [Parallel(n_jobs=1)]: Done  10 tasks       | elapsed:  5.7min
# [CV] n_estimators=280 ................................................
# [CV] ....................... n_estimators=280, score=0.808385 -  42.5s
# [Parallel(n_jobs=1)]: Done  11 tasks       | elapsed:  6.4min
# [CV] n_estimators=280 ................................................
# [CV] ....................... n_estimators=280, score=0.803981 -  44.0s
# [Parallel(n_jobs=1)]: Done  12 tasks       | elapsed:  7.2min
# [CV] n_estimators=280 ................................................
# [CV] ....................... n_estimators=280, score=0.813756 - 1.0min
# [Parallel(n_jobs=1)]: Done  13 tasks       | elapsed:  8.2min
# [CV] n_estimators=280 ................................................
# [CV] ....................... n_estimators=280, score=0.835159 -  44.5s
# [Parallel(n_jobs=1)]: Done  14 tasks       | elapsed:  9.0min
# [CV] n_estimators=280 ................................................
# [CV] ....................... n_estimators=280, score=0.818876 -  37.9s
# [Parallel(n_jobs=1)]: Done  15 tasks       | elapsed:  9.6min
# [CV] n_estimators=320 ................................................
# [CV] ....................... n_estimators=320, score=0.808293 -  46.9s
# [Parallel(n_jobs=1)]: Done  16 tasks       | elapsed: 10.4min
# [CV] n_estimators=320 ................................................
# [CV] ....................... n_estimators=320, score=0.805480 -  55.2s
# [Parallel(n_jobs=1)]: Done  17 tasks       | elapsed: 11.3min
# [CV] n_estimators=320 ................................................
# [CV] ....................... n_estimators=320, score=0.815268 -  55.9s
# [Parallel(n_jobs=1)]: Done  18 tasks       | elapsed: 12.2min
# [CV] n_estimators=320 ................................................
# [CV] ....................... n_estimators=320, score=0.835929 -  48.3s
# [Parallel(n_jobs=1)]: Done  19 tasks       | elapsed: 13.0min
# [CV] n_estimators=320 ................................................
# [CV] ....................... n_estimators=320, score=0.817664 -  50.3s
# [Parallel(n_jobs=1)]: Done  20 tasks       | elapsed: 13.9min
# [CV] n_estimators=360 ................................................
# [CV] ....................... n_estimators=360, score=0.811061 - 1.0min
# [Parallel(n_jobs=1)]: Done  21 tasks       | elapsed: 14.9min
# [CV] n_estimators=360 ................................................
# [CV] ....................... n_estimators=360, score=0.807314 - 1.0min
# [Parallel(n_jobs=1)]: Done  22 tasks       | elapsed: 15.9min
# [CV] n_estimators=360 ................................................
# [CV] ....................... n_estimators=360, score=0.812605 -  59.3s
# [Parallel(n_jobs=1)]: Done  23 tasks       | elapsed: 16.9min
# [CV] n_estimators=360 ................................................
# [CV] ....................... n_estimators=360, score=0.834994 -  51.8s
# [Parallel(n_jobs=1)]: Done  24 tasks       | elapsed: 17.8min
# [CV] n_estimators=360 ................................................
# [CV] ....................... n_estimators=360, score=0.818237 -  49.5s
# [Parallel(n_jobs=1)]: Done  25 tasks       | elapsed: 18.6min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 18.6min finished
